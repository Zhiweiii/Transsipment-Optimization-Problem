# %%
using Distributions

using JuMP
using CPLEX

# Demand distribution
mu = [100.0, 200, 150, 170, 180, 170, 170]
sigma = [20.0, 50, 30, 50, 40, 30, 50]

# For each location, we discretize the levels into
# low, medium, high, using quantiles.
q = [
    quantile(Normal(mu[i], sigma[i]), [1/6, 3/6, 5/6])
    for i in 1:7
]

const d = vec(collect(Iterators.product(q...)))

# Number of locations
const N = 7
# Out:
# 7

# %%
# Solve a subproblem given first stage decision s and demand realization d,
# and generate cut
function benders_cut(s, d)
    # holding cost 
    h = 1.0
    # shortage cost
    p = 4.0
    # transshipment cost
    c = 0.5

    # Sanity check
    @assert(length(s) == N)
    @assert(length(d) == N)

    # Build second stage model
    model = Model(CPLEX.Optimizer)

    # Suppress output for solving subproblems
    # to avoid cluttering the output
    set_silent(model)

    ij_set = [(i, j) for i=1:N for j=1:N if i!=j]
    @variables(model, begin
        e[1:N] >= 0
        f[1:N] >= 0
        q[1:N] >= 0
        r[1:N] >= 0
        t[ij_set] >= 0
    end)

    @objective(model, Min, h*sum(e) + c*sum(t) + p*sum(r))

    @constraints(model, begin
        B[i=1:N], f[i] + sum(t[(i,j)] for j=1:N if j!=i) + e[i] == s[i]
        M[i=1:N], f[i] + sum(t[(j,i)] for j=1:N if j!=i) + r[i] == d[i]
        R, sum(r) + sum(q) == sum(d)
        E[i=1:N], e[i] + q[i] == s[i]
    end)

    optimize!(model)

    # Get dual variables corresponding to that constraint
    pi_B = dual.(B)
    pi_M = dual.(M)
    pi_R = dual(R)
    pi_E = dual.(E)

    # Cut coefficients
    alpha = sum(d[i] * (pi_M[i] + pi_R) for i=1:N)
    beta = pi_B + pi_E
    
    obj = objective_value(model)
    dual_obj = alpha + beta'*s
    @assert(isapprox(obj, dual_obj), "obj=$obj, dual_obj=$dual_obj")
    
    return alpha, beta, dual_obj
end
# Out:
# benders_cut (generic function with 1 method)

# %%
# Given first stage decision s, go through each scenario
# to get an aggregated Benders cut.
function get_aggregate_cuts(s)
    a::Float64 = 0.0
    b::Vector{Float64} = zeros(N)
    d_obj::Float64 = 0.0

    for i in eachindex(d)
        alpha, beta, dual_obj = benders_cut(s, d[i])
        a += alpha / length(d)
        b += beta / length(d)
        d_obj += dual_obj / length(d)
    end

    return a, b, d_obj
end
# Out:
# get_aggregate_cuts (generic function with 1 method)

# %%
# Master problem
model = Model(CPLEX.Optimizer)

# Some initial bounds on s
@variable(model, 80 <= s[1:N] <= 300)
@variable(model, eta >= 0)
@objective(model, Min, eta)
# Suppress output
set_silent(model)
optimize!(model)

# TODO: Print out solutions, objective value and number of iterations

# %%
# Maximum number of iterations
MAX_ITER = 100

# Stopping criteria
ABSOLUTE_OPTIMALITY_GAP =  1e-6
@time begin
    for iter = 1:MAX_ITER
        # ====================
        # Hint:
        # Solve master problem to get lower_bound and new first stage decision.
        # Call get_aggregate_cuts on current first stage decision
        # to get alpha, beta, and upper_bound.
        # Add a new cut to the master problem.
        # TODO: fill in
        optimize!(model)
        lower_bound = objective_value(model)
        cut = get_aggregate_cuts(value.(s))
        alpha = cut[1]
        beta = cut[2]
        upper_bound = cut[3]

        gap = (upper_bound - lower_bound)
        println(iter)

        # =====================
        # Recommended: Display upper_bound and lower_bound
        @show value.(lower_bound)
        @show value.(upper_bound)

        @show value.(s)
        @show objective_value(model)

        # =====================
        # Stopping criteria
        # TODO: fill in

        new_cut = @constraint(model,eta>=alpha + beta'*s)

        if gap < ABSOLUTE_OPTIMALITY_GAP
            println("Terminating with the optimal solution")
            break
        end
    end
end
# Out:
# 1
# value.(lower_bound) = 0.0
# value.(upper_bound) = 2320.0
# value.(s) = [80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0]
# objective_value(model) = 0.0
# 2
# value.(lower_bound) = 0.0
# value.(upper_bound) = 337.418661144916
# value.(s) = [300.0, 300.0, 219.99999999996209, 80.0, 80.0, 80.0, 80.0]
# objective_value(model) = 0.0
# 3
# value.(lower_bound) = 0.0
# value.(upper_bound) = 364.65373072721803
# value.(s) = [300.0, 300.0, 300.0, 224.5109783554474, 80.0, 80.0, 80.0]
# objective_value(model) = 0.0
# 4
# value.(lower_bound) = 0.0
# value.(upper_bound) = 266.05085698939115
# value.(s) = [80.0, 80.0, 287.55802396597926, 80.0, 300.0, 300.0, 102.38330913087796]
# objective_value(model) = 0.0
# 5
# value.(lower_bound) = 10.01299978592779
# value.(upper_bound) = 263.9626343319123
# value.(s) = [137.37569020450107, 80.0, 80.0, 300.0, 80.0, 201.9406428923557, 300.0]
# objective_value(model) = 10.01299978592779
# 6
# value.(lower_bound) = 36.029822013461974
# value.(upper_bound) = 232.71671695527746
# value.(s) = [80.0, 300.0, 80.0, 129.76405396527102, 270.195807201519, 80.0, 300.0]
# objective_value(model) = 36.029822013461974
# 7
# value.(lower_bound) = 81.9994130233544
# value.(upper_bound) = 214.5158929944415
# value.(s) = [125.75540739556858, 300.0, 185.80144261711393, 80.0, 80.0, 253.65369341675728, 204.73078966741696]
# objective_value(model) = 81.9994130233544
# 8
# value.(lower_bound) = 82.91726673522561
# value.(upper_bound) = 239.6665896980983
# value.(s) = [294.21757641621593, 136.36678470081367, 137.70224247886947, 138.30096359314018, 300.0, 80.0, 129.93791917189608]
# objective_value(model) = 82.91726673522561
# 9
# value.(lower_bound) = 86.77755152119683
# value.(upper_bound) = 189.18370362263127
# value.(s) = [80.0, 269.16774132635504, 118.68047454414352, 255.3292923300396, 185.2914340947272, 219.03873126310788, 80.0]
# objective_value(model) = 86.77755152119683
# 10
# value.(lower_bound) = 92.14526101182423
# value.(upper_bound) = 170.439155416123
# value.(s) = [80.0, 169.87499241839043, 184.19085812411038, 251.64269580597468, 171.42874992892857, 191.23642888109526, 208.14509711324672]
# objective_value(model) = 92.14526101182423
# 11
# value.(lower_bound) = 105.65863683608387
# value.(upper_bound) = 166.90222643203506
# value.(s) = [80.0, 224.93831318386293, 168.28616620201674, 169.6788454084301, 166.84248101601833, 158.01050198796122, 206.96697286857983]
# objective_value(model) = 105.65863683608387
# 12
# value.(lower_bound) = 107.6012652066569
# value.(upper_bound) = 168.11298585791687
# value.(s) = [145.52315616933458, 254.65399851816377, 121.93579538913079, 229.10369758817714, 144.48269359530667, 139.07852173806126, 186.56585223934593]
# objective_value(model) = 107.6012652066569
# 13
# value.(lower_bound) = 108.47686706574001
# value.(upper_bound) = 154.05781763440646
# value.(s) = [108.80387360226025, 203.46872276318314, 118.72221281620847, 167.20200028230164, 197.45825793752294, 218.11943809055492, 207.13378862531076]
# objective_value(model) = 108.47686706574001
# 14
# value.(lower_bound) = 115.12522064625648
# value.(upper_bound) = 164.9990504319952
# value.(s) = [118.88472554615888, 226.76380378520693, 205.56277169534823, 186.61875220805447, 194.34791653263358, 181.01098265367432, 98.86354164934272]
# objective_value(model) = 115.12522064625648
# 15
# value.(lower_bound) = 119.3248906163078
# value.(upper_bound) = 160.04531197153395
# value.(s) = [110.25647273863187, 211.1893419977555, 197.30850256587766, 142.92819019707036, 198.4189990726666, 139.70791922485725, 228.70953992886788]
# objective_value(model) = 119.3248906163078
# 16
# value.(lower_bound) = 122.9307021602571
# value.(upper_bound) = 152.38610630021083
# value.(s) = [112.87725026644723, 164.70323721587096, 158.77756099341835, 216.53622011857215, 180.21207017390634, 167.38349252993757, 203.2207751227873]
# objective_value(model) = 122.9307021602571
# 17
# value.(lower_bound) = 128.15804366029187
# value.(upper_bound) = 156.4648603715258
# value.(s) = [80.0, 268.0748438184059, 171.49480201507836, 181.9860866382068, 152.06618875700315, 181.46922980124347, 189.94769679874685]
# objective_value(model) = 128.15804366029187
# 18
# value.(lower_bound) = 129.31018451625826
# value.(upper_bound) = 157.8113554480592
# value.(s) = [137.089827862971, 221.42384015043476, 171.56970900571403, 189.7817641636379, 164.447244209197, 186.0439067293446, 181.55276334823174]
# objective_value(model) = 129.31018451625826
# 19
# value.(lower_bound) = 131.65974544472934
# value.(upper_bound) = 162.5521707147377
# value.(s) = [80.0, 219.27816985775024, 164.5573718273913, 178.62388639588534, 262.0257071321354, 175.3168771152611, 171.17121371857132]
# objective_value(model) = 131.65974544472934
# 20
# value.(lower_bound) = 133.67757850260983
# value.(upper_bound) = 154.97768352724168
# value.(s) = [114.06243241020174, 268.0795547945103, 148.60982156592988, 162.06767536133802, 220.442079937346, 149.12571286893444, 162.0567534289695]
# objective_value(model) = 133.67757850260983
# 21
# value.(lower_bound) = 133.69106384925539
# value.(upper_bound) = 153.0325822201003
# value.(s) = [102.12790063001552, 227.33020857214538, 186.6789551427404, 128.79258251657254, 202.54028226706626, 193.01040218609845, 181.50599462667685]
# objective_value(model) = 133.69106384925539
# 22
# value.(lower_bound) = 134.29585465174083
# value.(upper_bound) = 147.6491568704323
# value.(s) = [101.98470665752707, 229.8893642633243, 145.28541948688365, 200.3878224910235, 202.32549130833365, 184.87890544370856, 158.7198171880497]
# objective_value(model) = 134.29585465174083
# 23
# value.(lower_bound) = 136.69366500485455
# value.(upper_bound) = 153.50141257256323
# value.(s) = [84.82666739607748, 183.29503166214982, 154.96345723581754, 196.6070554260547, 176.58843241615884, 213.91301869051102, 215.7027879374693]
# objective_value(model) = 136.69366500485455
# 24
# value.(lower_bound) = 137.0382565067708
# value.(upper_bound) = 149.562969137471
# value.(s) = [94.52275931213399, 218.19383308060526, 141.38179907398768, 182.06291755197057, 191.13257029024624, 173.16804420501072, 228.32196638704409]
# objective_value(model) = 137.0382565067708
# 25
# value.(lower_bound) = 138.0494365411314
# value.(upper_bound) = 151.50463555068103
# value.(s) = [114.93166173287635, 233.03038432560754, 144.46986576374204, 170.26123632678627, 150.26156877882374, 182.4322442742742, 210.3441517823601]
# objective_value(model) = 138.0494365411314
# 26
# value.(lower_bound) = 138.22189397023615
# value.(upper_bound) = 145.94046304427854
# value.(s) = [96.17955597225948, 217.58765115497494, 168.8361396100326, 201.35485828218543, 179.05039523856976, 170.2988836936295, 192.70522604516228]
# objective_value(model) = 138.22189397023615
# 27
# value.(lower_bound) = 139.3745111832574
# value.(upper_bound) = 146.8362685636207
# value.(s) = [120.51071641066365, 191.73849745273145, 148.83180082634573, 173.98771131603468, 193.66784106207257, 190.76114443577677, 205.34675664639312]
# objective_value(model) = 139.3745111832574
# 28
# value.(lower_bound) = 139.38913312509064
# value.(upper_bound) = 149.1099160422017
# value.(s) = [117.18507475643418, 230.17400042435014, 153.01843682295817, 179.35158365282462, 198.17071905648146, 147.91253539170506, 202.33735698995736]
# objective_value(model) = 139.38913312509064
# 29
# value.(lower_bound) = 139.87300663977447
# value.(upper_bound) = 146.27558809275504
# value.(s) = [99.23472476133799, 209.3436089189775, 147.26950578739337, 164.97368007141773, 207.4920965057309, 185.41799337414716, 199.45731547967983]
# objective_value(model) = 139.87300663977447
# 30
# value.(lower_bound) = 140.248132855782
# value.(upper_bound) = 146.2579198320428
# value.(s) = [98.72896865705462, 192.2922721714413, 164.16822784974025, 182.22554355285837, 208.35099402911447, 191.31491915451042, 182.9117348364291]
# objective_value(model) = 140.248132855782
# 31
# value.(lower_bound) = 140.47690103685946
# value.(upper_bound) = 144.9079993197825
# value.(s) = [111.29070337789491, 211.48564287325394, 160.77109352579885, 174.52479279390147, 191.48564287325604, 180.77109352580155, 182.0052527253456]
# objective_value(model) = 140.47690103685946
# 32
# value.(lower_bound) = 142.8288516755627
# value.(upper_bound) = 152.07915130647785
# value.(s) = [107.5815329502636, 213.97382486292082, 152.65740233620494, 165.1901131663236, 210.72073074743813, 206.9948539917218, 188.89795547693376]
# objective_value(model) = 142.8288516755627
# 33
# value.(lower_bound) = 143.21232071415793
# value.(upper_bound) = 148.87796468434763
# value.(s) = [105.45862533710084, 211.41841020521287, 145.15103615574517, 197.37699340535346, 191.41841020521508, 197.25474041137514, 191.72599938656575]
# objective_value(model) = 143.21232071415793
# 34
# value.(lower_bound) = 143.21232071415733
# value.(upper_bound) = 150.13482361509296
# value.(s) = [105.45862533709337, 211.4184102052189, 179.14489997704598, 197.37699340535335, 191.41841020522133, 197.25474041136832, 157.7321355652672]
# objective_value(model) = 143.21232071415733
# 35
# value.(lower_bound) = 143.403814570339
# value.(upper_bound) = 147.13561398103914
# value.(s) = [108.57997519285404, 205.96083530404388, 172.36601746821748, 185.73416694951445, 185.96083530404593, 192.39079646435744, 185.70938795339552]
# objective_value(model) = 143.403814570339
# 36
# value.(lower_bound) = 144.28534199019563
# value.(upper_bound) = 154.58695587100408
# value.(s) = [122.94887213652805, 218.22210823236625, 170.82443807619708, 179.3820550376548, 160.8373038381182, 217.24475521543818, 152.96173789844832]
# objective_value(model) = 144.28534199019563
# 37
# value.(lower_bound) = 144.2853419901962
# value.(upper_bound) = 152.11909462593707
# value.(s) = [92.04403049403808, 218.22210823236708, 170.82443807620376, 179.38205503765283, 191.74214548060402, 217.24475521543945, 152.96173789843664]
# objective_value(model) = 144.2853419901962
# 38
# value.(lower_bound) = 144.28534199019555
# value.(upper_bound) = 147.40726006697693
# value.(s) = [107.71153576555945, 202.1799195005201, 186.117259887381, 180.88078887897402, 176.07464020909018, 201.2025664835918, 168.25455970963338]
# objective_value(model) = 144.28534199019555
# 39
# value.(lower_bound) = 144.28534199019623
# value.(upper_bound) = 147.44526916094264
# value.(s) = [107.71153576555757, 211.24802725901287, 167.38575142658414, 172.40797406429766, 176.07464020908515, 210.27067424208468, 177.32266746812095]
# objective_value(model) = 144.28534199019623
# 40
# value.(lower_bound) = 144.28534199019546
# value.(upper_bound) = 149.2269944214082
# value.(s) = [116.71804528101993, 187.06813069362846, 176.3922609420464, 171.46143007064245, 194.08765924000886, 209.32413024841145, 167.36961395899223]
# objective_value(model) = 144.28534199019546
# 41
# value.(lower_bound) = 144.28534199019543
# value.(upper_bound) = 145.72109828935533
# value.(s) = [101.89308798732533, 201.8930879873164, 182.38337188692577, 177.14690087851866, 185.2538128911929, 200.4902838995971, 173.36072490387343]
# objective_value(model) = 144.28534199019543
# 42
# value.(lower_bound) = 144.2853419901957
# value.(upper_bound) = 145.12671442898892
# value.(s) = [102.52411731643878, 202.52411731642985, 177.7605883248282, 193.1139178104524, 181.26205865820972, 196.4985296666135, 168.73794134177413]
# objective_value(model) = 144.2853419901957
# 43
# value.(lower_bound) = 144.28534199019546
# value.(upper_bound) = 144.91637131928564
# value.(s) = [99.99999999999615, 203.78617597465058, 175.23647100838505, 186.80362451935224, 183.78617597465228, 199.02264698305402, 173.78617597465944]
# objective_value(model) = 144.28534199019546
# 44
# value.(lower_bound) = 144.28534199019552
# value.(upper_bound) = 145.19660796623845
# value.(s) = [104.34664926855933, 199.43952670608746, 179.5831202769482, 191.15027378791362, 179.4395267060901, 194.6759977144915, 173.78617597465941]
# objective_value(model) = 144.28534199019552
# 45
# value.(lower_bound) = 144.28534199019543
# value.(upper_bound) = 145.2280434507164
# value.(s) = [100.9580715930368, 202.82810438160894, 180.89267977163675, 187.76169611239285, 182.82810438161198, 193.3664382198024, 173.78617597465976]
# objective_value(model) = 144.28534199019543
# 46
# value.(lower_bound) = 144.2853419901963
# value.(upper_bound) = 144.91637131928627
# value.(s) = [103.78617597465967, 199.99999999998465, 175.23647100839025, 195.15305188707728, 179.99999999998676, 194.45939558999837, 173.78617597465632]
# objective_value(model) = 144.2853419901963
# 47
# value.(lower_bound) = 144.28534199019597
# value.(upper_bound) = 145.7274121498072
# value.(s) = [95.13375501686906, 208.65242095777543, 175.23647100838895, 189.8444704697431, 188.65242095777754, 191.1155560495402, 173.78617597465768]
# objective_value(model) = 144.28534199019597
# 48
# value.(lower_bound) = 144.28534199019634
# value.(upper_bound) = 144.91637131928596
# value.(s) = [103.7861759746583, 199.9999999999845, 175.23647100839077, 179.01198588980503, 196.1410659972612, 194.4593955899982, 173.7861759746558]
# objective_value(model) = 144.28534199019634
# 49
# value.(lower_bound) = 144.2853419901962
# value.(upper_bound) = 144.91637131928576
# value.(s) = [103.78617597465919, 218.77634207843622, 175.23647100839014, 176.37670980862708, 179.9999999999863, 194.45939558999763, 173.78617597465643]
# objective_value(model) = 144.2853419901962
# 50
# value.(lower_bound) = 144.2853419901955
# value.(upper_bound) = 145.7705823922313
# value.(s) = [103.78617597466203, 218.77634207845261, 170.1112045707252, 164.87473356232329, 196.62724268393308, 194.45939558999424, 173.78617597465927]
# objective_value(model) = 144.2853419901955
# 51
# value.(lower_bound) = 144.28534199019617
# value.(upper_bound) = 144.91637131928533
# value.(s) = [103.78617597465936, 218.77634207844147, 175.23647100838926, 173.78617597465157, 196.6272426839215, 180.42268674003324, 173.7861759746566]
# objective_value(model) = 144.28534199019617
# 52
# value.(lower_bound) = 144.59568428320085
# value.(upper_bound) = 144.59568428318084
# value.(s) = [99.99999999999632, 219.3484313219802, 179.022646983053, 169.99999999998883, 180.00000000000952, 199.02264698304091, 169.99999999999375]
# objective_value(model) = 144.59568428320085
# Terminating with the optimal solution
#  61.049975 seconds (535.70 M allocations: 24.175 GiB, 5.95% gc time, 0.04% compilation time)

# %%
benders_cut(s, d)
